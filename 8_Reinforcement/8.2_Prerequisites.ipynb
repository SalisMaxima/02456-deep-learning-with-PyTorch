# %% [markdown]
# # Prerequisites
#
# > By Jonas Busk ([jbusk@dtu.dk](mailto:jbusk@dtu.dk))
#
# **2019 update:** Changes have been made to the display of environments due to the previous `viewer` being incompatible with newer versions of Gym.
#
# **2022 update:** Rendering was disabled, and the notebook now uses the `colabgymrender` package to render a video.
#
# **2023 update:** Changed to packages `gymnasium` and `renderlab`, and to `CartPole-v1`.
#
# In this lab we will create neural network reinforcement learning agents with [PyTorch](https://pytorch.org/) to navigate various environments from [Gymnasium](https://github.com/Farama-Foundation/Gymnasium) originally developed by [OpenAI](https://openai.com/).
#
# Please refer to the [docs](https://gymnasium.farama.org) on how to get started with Gymnasium.

# %% [markdown]
# ## Installation
#
# Below is a brief guide on how to install Gymnasium. For more details, please refer to the repository on [GitHub](https://gymnasium.farama.org) and the [docs](https://gym.openai.com/docs).
#
# You can do a minimal install of the packaged version of Gym directly from PyPI:
#
# ```
# pip install gymnasium
# ```
#
# If you run in Colab, you can do a quick pip install of Gym in the cell below:

# %%
# !pip install gymnasium
# !pip install renderlab
# Out:
# Requirement already satisfied: gymnasium in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from gymnasium) (1.26.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: renderlab in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (0.1.20230421184216)
# Requirement already satisfied: moviepy in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from renderlab) (1.0.3)
# Requirement already satisfied: gymnasium in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from renderlab) (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from gymnasium->renderlab) (1.26.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from gymnasium->renderlab) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from gymnasium->renderlab) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from gymnasium->renderlab) (0.0.4)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from moviepy->renderlab) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from moviepy->renderlab) (4.66.6)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from moviepy->renderlab) (2.32.2)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from moviepy->renderlab) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from moviepy->renderlab) (2.36.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from moviepy->renderlab) (0.5.1)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from imageio<3.0,>=2.5->moviepy->renderlab) (10.2.0)
# Requirement already satisfied: setuptools in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy->renderlab) (69.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\mathi\anaconda3\envs\navierstokes\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy->renderlab) (0.4.6)

# %% [markdown]
# ## Running an environment
#
# Here is a bare minimum example of running a Gym environment. This creates an instance of the [CartPole-v0](https://gym.openai.com/envs/CartPole-v0) environment and runs until the rollout is done, taking random actions and rendering the environment at each step. With Gym installed, you should be able to see a small animation of the environment below.

# %%
import gymnasium as gym
import renderlab as rl

env = gym.make("CartPole-v1", render_mode = "rgb_array") # Create the environment
env = rl.RenderFrame(env, "./output") # Directory for the recorded video
env.reset()

# Run environment
while True:
    action = env.action_space.sample() # Get a random action
    _, _, done, _, _ = env.step(action) # Take a step
    if done: break # Break if environment is done

env.close() # Close environment
env.play() # Show the video
# Out:
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# Hooray! You now have a working `Gym` environment that we can take actions in and render.
